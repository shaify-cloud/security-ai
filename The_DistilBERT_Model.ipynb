# %% [markdown]
# <a href="https://colab.research.google.com/github/shaify-cloud/security-ai/blob/main/The_DistilBERT_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q transformers torch

# %%
from transformers import pipeline

# Initialize the text classification pipeline
classifier = pipeline(
    "text-classification",
    model="distilbert-base-uncased-finetuned-sst-2-english",
    framework="pt"
)

# Input text
log_text = (
 """
    I'm sick and tired of getting dumped on.
 """
)

# Perform classification
result = classifier(log_text)

# Print result
print(result)
# Out:
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# [{'label': 'NEGATIVE', 'score': 0.9992558360099792}]

# %%
from transformers import pipeline

# Initialize the text classification pipeline
classifier = pipeline(
    "text-classification",
    model="distilbert-base-uncased-finetuned-sst-2-english",
    framework="pt"
)

# Input text
log_text = (
 """
    I love this company and enjoy working here..
 """
)

# Perform classification
result = classifier(log_text)

# Print result
print(result)
# Out:
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# [{'label': 'POSITIVE', 'score': 0.9998716115951538}]
